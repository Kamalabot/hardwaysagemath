# %% [markdown]
# https://youtu.be/4QZwb_0OOxY?si=PQIay6uKw5XdTxHG

# %%
# solve function in sage

solve??

# %%
f(x) = x ^ 2 + 60 * x + 5

# %%
show(f(x))
# Out:
# x^2 + 60*x + 5

# %%
latex(f(x))
# Out:
# x^{2} + 60 \, x + 5

# %%
f(pi).n()
# Out:
# 203.365163616477

# %%
solve(f(x) == 0, x, solution_dict=True)
# Out:
# [{x: -sqrt(895) - 30}, {x: sqrt(895) - 30}]

# %%
f.coefficients()
# Out:
# [[x |--> 5, x |--> 0], [x |--> 60, x |--> 1], [x |--> 1, x |--> 2]]

# %%
f.roots()
# Out:
# [(-sqrt(895) - 30, 1), (sqrt(895) - 30, 1)]

# %%
(x^2+x+1).roots()
# Out:
# [(-1/2*I*sqrt(3) - 1/2, 1), (1/2*I*sqrt(3) - 1/2, 1)]

# %%
var('a,b,c')
sol = solve(a*x^2+b*x+c==0, x)

# %%
show(sol)
# Out:
# [x == -1/2*(b + sqrt(b^2 - 4*a*c))/a, x == -1/2*(b - sqrt(b^2 - 4*a*c))/a]

# %%
var('x, y')
# Out:
# (x, y)

# %%
solve([x+y==6, x-y==4], [x, y], solution_dict=True)
# Out:
# [{x: 5, y: 1}]

# %%
var('x, y')

x = solve([x^2+y==1, x*y==1/4], [x,y], solution_dict=True)

# %%
show(x)
# Out:
# [{x: 0.2695944526160958, y: 0.9273188740193816},
#  {x: 0.8375654977831519, y: 0.2984841381465854},
#  {x: -1.1071597913703177, y: -0.2258029747790472}]

# %%
for soln in x:
    print(soln)
# Out:
# {x: 0.2695944526160958, y: 0.9273188740193816}
# {x: 0.8375654977831519, y: 0.2984841381465854}
# {x: -1.1071597913703177, y: -0.2258029747790472}

# %%
var('x')
# Out:
# x

# %%
solve(x^-2*x - 1 > 8, x, solution_dict=True)
# Out:
# [[x > 0, x < (1/9)]]

# %%
var('x,y')
# Out:
# (x, y)

# %%
g(x, y) = x^2+2*x*y-3*y+exp(-x^2-y^2)

# %% [markdown]
# ![image.png](attachment:image.png)

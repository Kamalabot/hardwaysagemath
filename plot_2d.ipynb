# %%
f(x) = x * cos(1/x)

# %%
f.plot()
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f.plot(-0.1, 0.1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot??
# Out:
# Signature: plot(funcs, *args, **kwds)
# Docstring:
#    Use plot by writing
#
#    "plot(X, ...)"
#
#    where X is a Sage object (or list of Sage objects) that either is
#    callable and returns numbers that can be coerced to floats, or has
#    a plot method that returns a "GraphicPrimitive" object.
#
#    There are many other specialized 2D plot commands available in
#    Sage, such as "plot_slope_field", as well as various graphics
#    primitives like "Arrow"; type "sage.plot.plot?" for a current list.
#
#    Type "plot.options" for a dictionary of the default options for
#    plots. You can change this to change the defaults for all future
#    plots. Use "plot.reset()" to reset to the default options.
#
#    PLOT OPTIONS:
#
#    * "plot_points" -- (default: 200); the minimal number of plot
#      points.
#
#    * "adaptive_recursion" -- (default: 5); how many levels of
#      recursion to go before giving up when doing adaptive refinement.
# ...

# %%
plot(f, (x, -0.1, 0.1), figsize=4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f, (x, -0.1, 0.1), figsize=4, thickness=0.5, color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1 = plot(f, (x, -0.1, 0.1), figsize=6, color='green', legend_label='Green')

# %%
f2 = plot(x, -0.1, 0.1, color='red', legend_label='y=x')

# %%
show(f1+f2, figsize=4)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
xp = piecewise([((0,1), 1 + x^3), ([-1,0] , 1+x)])

# %%
xp.plot(-2, 2)
# Out:
# verbose 0 (3935: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 101 points.
# verbose 0 (3935: plot.py, generate_plot_points) Last error message: 'Unable to compute f(2.0)'
# Graphics object consisting of 1 graphics primitive

# %%
f1(x) = -1
f2(x) = 1 - x^2
f3(x) = 2*x - 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fful = piecewise([[(-1, 0.5), f1], [(0.5, 1.5), f2], [(1.5, 2.5), f3]])

# %%
fful.plot()
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1 = plot(floor(x), -5, 5)
f2 = plot(floor(x), -5, 5, exclude=[-4..0.5])
f2.inset(f1, pos=(0.25, 0.6, 0.2, 0.2))
# this is upto 16 mins in the video
# Out:
# Multigraphics with 2 elements

# %%
var('x,y')

n = 3

f(x,y) = x^n+y^n-1
implicit_plot(f, (x, -2, 2), (y, -2, 2), color='rosybrown')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
len(colors.items())
# Out:
# 148

# %%
# parametric plot

var('t')

p = parametric_plot([t * sin(1 - t^2), t* cos(t^2)], (t, -2*pi, 2*pi), color='red', thickness=1.2)

# %%
txt = text('Nice Plot', (-4, 4))
show(p + txt, figsize=5)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
var('theta')
s = 0.5
polar_plot(1 + 2 * cos(s * theta), (theta, 0, 200*pi), plot_points=5000, thickness=0.5, figsize=4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
p1 = polar_plot(0.5 * cos(4*t) + 2.5, 0, 2*pi, color='red')
p2 = polar_plot(cos(4 *t) + 1.5, 0, 2*pi, fill=0.5 * cos(4*t) + 2.5, fillcolor='lightblue')

# %%
show(p1+p2, figsize=4)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
region_plot([x*y<=1/2, x*y>=-1/2], (x,-2, 2), (y, -2, 2), incol='red', outcol='lightgreen', figsize=4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
polygon2d([[-1, 0], [0, -1], [1, 0], [0, 1]], color='goldenrod', edgecolor='black')
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ![image.png](attachment:image.png)
